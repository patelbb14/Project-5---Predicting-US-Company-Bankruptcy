# %% [markdown]
# # **Recurrent Neural Network (RNN) Model**

# %% [markdown]
# After testing different models for bankruptcy prediction, we decided to implement RNN because RNNs are adept at handling sequential data, allowing us to capture temporal dependencies in financial indicators that could be crucial for identifying patterns leading to bankruptcy.
#
# With the RNN we were able to obtain an accuracy of 90% which is still lower than the baseline of 93%.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix


from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau

from keras.preprocessing.sequence import pad_sequences
from imblearn.over_sampling import SMOTE

from keras.regularizers import l2

# %%
# Read data
from google.colab import drive
drive.mount('/content/drive/')
file_path = '/content/drive/MyDrive/[1] DSI Drive/[2] Projects/Project 5/data/american_bankruptcy.csv'
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive/

# %%
df['status_label'] = np.where(df['status_label'] == 'alive', 1, 0)

# %%
df['status_label'].value_counts()
# Out:
# 1    73462
# 0     5220
# Name: status_label, dtype: int64

# %%
df.head()
# Out:
#   company_name  status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1             1  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1             1  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1             1  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1             1  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1             1  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...        X9      X10      X11     X12      X13      X14  \
# 0  35.163  128.348  ...  1024.333  740.998  180.447  70.658  191.226  163.816
# 1  18.531  115.187  ...   874.255  701.854  179.987  45.790  160.444  125.392
# 2 -58.939   77.528  ...   638.721  710.199  217.699   4.711  112.244  150.464
# 3 -12.410   66.322  ...   606.337  686.621  164.658   3.573  109.590  203.575
# 4   3.504  104.661  ...   651.958  709.292  248.666  20.811  128.656  131.261
#
#        X15       X16      X17      X18
# 0  201.026  1024.333  401.483  935.302
# 1  204.065   874.255  361.642  809.888
# 2  139.603   638.721  399.964  611.514
# 3  124.106   606.337  391.633  575.592
# 4  131.884   651.958  407.608  604.467
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['company_name', 'status_label', 'year', 'X1', 'X2', 'X3', 'X4', 'X5',
#        'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16',
#        'X17', 'X18'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import numpy as np
from keras.preprocessing.sequence import pad_sequences
from imblearn.over_sampling import SMOTE

# Assuming 'df' is your DataFrame

# Sort the DataFrame by company_name and year
df_sorted = df.sort_values(by=['company_name', 'year'])

# Group the data by company_name and create sequences
sequences = []
targets = []
for company, group in df_sorted.groupby('company_name'):
    features = group.drop(columns=['company_name', 'status_label', 'year']).values
    target = group['status_label'].values[-1]  # Get the last status_label for each company
    sequences.append(features)
    targets.append(target)

# Pad sequences to have the same length
max_sequence_length = max(len(sequence) for sequence in sequences)
sequences_padded = pad_sequences(sequences, maxlen=max_sequence_length, dtype='float64', padding='post')

# Convert targets to a numpy array
targets = np.array(targets)

# Flatten the sequences for SMOTE
sequences_flattened = sequences_padded.reshape(sequences_padded.shape[0], -1)

# Split the data into training and test sets
X_train_flat, X_test_flat, y_train, y_test = train_test_split(sequences_flattened, targets, test_size=0.2, random_state=42)

# Use SMOTE to oversample the minority class in the training set
smote = SMOTE(random_state=42)
X_train_res_flat, y_train_res = smote.fit_resample(X_train_flat, y_train)

# Reshape the data back into sequences
X_train_res = X_train_res_flat.reshape(-1, max_sequence_length, sequences_padded.shape[2])
X_test = X_test_flat.reshape(-1, max_sequence_length, sequences_padded.shape[2])

# Scale the data
scaler = StandardScaler()
X_train_res_scaled = scaler.fit_transform(X_train_res.reshape(-1, X_train_res.shape[-1])).reshape(X_train_res.shape)
X_test_scaled = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# Build the RNN model
model = Sequential([
    LSTM(64, activation='relu', input_shape=(X_train_res_scaled.shape[1], X_train_res_scaled.shape[2])),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train_res_scaled, y_train_res, validation_data=(X_test_scaled, y_test),
                    epochs=50, batch_size=32, callbacks=[early_stopping])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 420/420 [==============================] - 17s 27ms/step - loss: 0.6760 - accuracy: 0.5918 - val_loss: 0.6122 - val_accuracy: 0.8479
# Epoch 2/50
# 420/420 [==============================] - 11s 25ms/step - loss: 0.6225 - accuracy: 0.6493 - val_loss: 0.5174 - val_accuracy: 0.8518
# Epoch 3/50
# 420/420 [==============================] - 12s 27ms/step - loss: 0.5870 - accuracy: 0.6675 - val_loss: 0.6871 - val_accuracy: 0.6251
# Epoch 4/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.5645 - accuracy: 0.6834 - val_loss: 0.4337 - val_accuracy: 0.8869
# Epoch 5/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.5392 - accuracy: 0.7015 - val_loss: 0.7620 - val_accuracy: 0.3877
# Epoch 6/50
# 420/420 [==============================] - 15s 35ms/step - loss: 0.5174 - accuracy: 0.7189 - val_loss: 0.7522 - val_accuracy: 0.7755
# Epoch 7/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.5171 - accuracy: 0.7320 - val_loss: 0.4842 - val_accuracy: 0.8401
# Epoch 8/50
# 420/420 [==============================] - 12s 29ms/step - loss: 0.4995 - accuracy: 0.7408 - val_loss: 0.3723 - val_accuracy: 0.8813
# Epoch 9/50
# 420/420 [==============================] - 14s 32ms/step - loss: 0.4814 - accuracy: 0.7553 - val_loss: 0.5481 - val_accuracy: 0.7159
# Epoch 10/50
# 420/420 [==============================] - 14s 34ms/step - loss: 0.4671 - accuracy: 0.7655 - val_loss: 0.6274 - val_accuracy: 0.6201
# Epoch 11/50
# 420/420 [==============================] - 11s 25ms/step - loss: 0.5389 - accuracy: 0.7567 - val_loss: 0.5138 - val_accuracy: 0.7538
# Epoch 12/50
# 420/420 [==============================] - 11s 26ms/step - loss: 0.4661 - accuracy: 0.7712 - val_loss: 0.4484 - val_accuracy: 0.7950
# Epoch 13/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.4542 - accuracy: 0.7759 - val_loss: 0.5743 - val_accuracy: 0.7064
# Epoch 14/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.4453 - accuracy: 0.7794 - val_loss: 0.3955 - val_accuracy: 0.8418
# Epoch 15/50
# 420/420 [==============================] - 12s 28ms/step - loss: 0.4350 - accuracy: 0.7872 - val_loss: 0.6518 - val_accuracy: 0.6396
# Epoch 16/50
# 420/420 [==============================] - 12s 27ms/step - loss: 0.4274 - accuracy: 0.7966 - val_loss: 0.5328 - val_accuracy: 0.7164
# Epoch 17/50
# 420/420 [==============================] - 12s 29ms/step - loss: 0.4205 - accuracy: 0.8014 - val_loss: 0.4855 - val_accuracy: 0.7744
# Epoch 18/50
# 420/420 [==============================] - 10s 24ms/step - loss: 0.4180 - accuracy: 0.7953 - val_loss: 0.3913 - val_accuracy: 0.8284
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3723 - accuracy: 0.8813
# Test accuracy: 0.8813

# %%
from keras.regularizers import l2

# Build the improved RNN model
model_improved = Sequential([
    LSTM(128, activation='relu', input_shape=(X_train_res_scaled.shape[1], X_train_res_scaled.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    LSTM(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile the improved model
model_improved.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Train the improved model
history_improved = model_improved.fit(X_train_res_scaled, y_train_res, validation_data=(X_test_scaled, y_test),
                                      epochs=50, batch_size=32, callbacks=[early_stopping])

# Evaluate the improved model
test_loss_improved, test_accuracy_improved = model_improved.evaluate(X_test_scaled, y_test)
print(f"Improved test accuracy: {test_accuracy_improved:.4f}")
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 420/420 [==============================] - 30s 64ms/step - loss: 0.7540 - accuracy: 0.5793 - val_loss: 0.4362 - val_accuracy: 0.9120
# Epoch 2/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.6211 - accuracy: 0.6511 - val_loss: 0.3284 - val_accuracy: 0.9086
# Epoch 3/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.5894 - accuracy: 0.6934 - val_loss: 0.7042 - val_accuracy: 0.4401
# Epoch 4/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.5559 - accuracy: 0.7098 - val_loss: 1.7926 - val_accuracy: 0.3226
# Epoch 5/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.5422 - accuracy: 0.7197 - val_loss: 0.8310 - val_accuracy: 0.4078
# Epoch 6/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.5251 - accuracy: 0.7276 - val_loss: 1.0921 - val_accuracy: 0.3354
# Epoch 7/50
# 420/420 [==============================] - 39s 93ms/step - loss: 0.5148 - accuracy: 0.7453 - val_loss: 0.2992 - val_accuracy: 0.9025
# Epoch 8/50
# 420/420 [==============================] - 29s 69ms/step - loss: 0.7344 - accuracy: 0.7643 - val_loss: 0.7365 - val_accuracy: 0.6039
# Epoch 9/50
# 420/420 [==============================] - 28s 67ms/step - loss: 0.6526 - accuracy: 0.7756 - val_loss: 0.3602 - val_accuracy: 0.8786
# Epoch 10/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.5080 - accuracy: 0.7730 - val_loss: 0.4184 - val_accuracy: 0.8501
# Epoch 11/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.4797 - accuracy: 0.7787 - val_loss: 1.0863 - val_accuracy: 0.3822
# Epoch 12/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4640 - accuracy: 0.7851 - val_loss: 0.4902 - val_accuracy: 0.8178
# Epoch 13/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4604 - accuracy: 0.7864 - val_loss: 0.4895 - val_accuracy: 0.8195
# Epoch 14/50
# 420/420 [==============================] - 26s 61ms/step - loss: 0.4524 - accuracy: 0.7934 - val_loss: 0.8068 - val_accuracy: 0.4730
# Epoch 15/50
# 420/420 [==============================] - 25s 59ms/step - loss: 0.4492 - accuracy: 0.7978 - val_loss: 0.6060 - val_accuracy: 0.8997
# Epoch 16/50
# 420/420 [==============================] - 26s 62ms/step - loss: 0.4472 - accuracy: 0.8006 - val_loss: 0.5226 - val_accuracy: 0.7911
# Epoch 17/50
# 420/420 [==============================] - 26s 62ms/step - loss: 0.4723 - accuracy: 0.8028 - val_loss: 0.7349 - val_accuracy: 0.6774
# 57/57 [==============================] - 1s 9ms/step - loss: 0.2992 - accuracy: 0.9025
# Improved test accuracy: 0.9025

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Build the improved RNN model
model_improved_2 = Sequential([
    LSTM(64, activation='relu', input_shape=(X_train_res_scaled.shape[1], X_train_res_scaled.shape[2]), return_sequences=True),
    Dropout(0.3),
    BatchNormalization(),
    LSTM(32, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),
    Dense(1, activation='sigmoid')
])

# Compile the model
model_improved_2.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history_improved_2 = model_improved_2.fit(X_train_res_scaled, y_train_res, validation_data=(X_test_scaled, y_test),
                                          epochs=50, batch_size=32, callbacks=[early_stopping])

# Evaluate the model
test_loss, test_accuracy = model_improved_2.evaluate(X_test_scaled, y_test)
print(f"Improved test accuracy: {test_accuracy:.4f}")
# Out:
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
# 420/420 [==============================] - 36s 70ms/step - loss: 0.6769 - accuracy: 0.6164 - val_loss: 0.7401 - val_accuracy: 0.3226
# Epoch 2/50
# 420/420 [==============================] - 29s 69ms/step - loss: 0.5652 - accuracy: 0.7000 - val_loss: 0.5835 - val_accuracy: 0.8774
# Epoch 3/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.5348 - accuracy: 0.7200 - val_loss: 0.5123 - val_accuracy: 0.8702
# Epoch 4/50
# 420/420 [==============================] - 28s 66ms/step - loss: 0.5094 - accuracy: 0.7364 - val_loss: 0.4874 - val_accuracy: 0.8930
# Epoch 5/50
# 420/420 [==============================] - 28s 66ms/step - loss: 0.4856 - accuracy: 0.7581 - val_loss: 0.4482 - val_accuracy: 0.8786
# Epoch 6/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4731 - accuracy: 0.7652 - val_loss: 0.4205 - val_accuracy: 0.8641
# Epoch 7/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4669 - accuracy: 0.7660 - val_loss: 0.4711 - val_accuracy: 0.8390
# Epoch 8/50
# 420/420 [==============================] - 28s 67ms/step - loss: 0.4620 - accuracy: 0.7713 - val_loss: 0.3957 - val_accuracy: 0.9042
# Epoch 9/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4525 - accuracy: 0.7751 - val_loss: 0.3613 - val_accuracy: 0.9047
# Epoch 10/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.4425 - accuracy: 0.7831 - val_loss: 0.4427 - val_accuracy: 0.8201
# Epoch 11/50
# 420/420 [==============================] - 27s 63ms/step - loss: 0.4256 - accuracy: 0.7935 - val_loss: 0.5854 - val_accuracy: 0.6306
# Epoch 12/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4243 - accuracy: 0.7976 - val_loss: 0.7776 - val_accuracy: 0.4618
# Epoch 13/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4232 - accuracy: 0.7962 - val_loss: 0.6050 - val_accuracy: 0.5376
# Epoch 14/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.4117 - accuracy: 0.8046 - val_loss: 0.6342 - val_accuracy: 0.5226
# Epoch 15/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4013 - accuracy: 0.8097 - val_loss: 0.3471 - val_accuracy: 0.8602
# Epoch 16/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.4058 - accuracy: 0.8010 - val_loss: 0.4858 - val_accuracy: 0.7109
# Epoch 17/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3923 - accuracy: 0.8105 - val_loss: 0.4886 - val_accuracy: 0.7348
# Epoch 18/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3844 - accuracy: 0.8201 - val_loss: 0.5654 - val_accuracy: 0.5989
# Epoch 19/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3855 - accuracy: 0.8170 - val_loss: 0.5339 - val_accuracy: 0.6942
# Epoch 20/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3726 - accuracy: 0.8249 - val_loss: 0.6960 - val_accuracy: 0.5382
# Epoch 21/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3771 - accuracy: 0.8213 - val_loss: 0.3128 - val_accuracy: 0.9031
# Epoch 22/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3708 - accuracy: 0.8287 - val_loss: 0.5063 - val_accuracy: 0.7304
# Epoch 23/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3677 - accuracy: 0.8259 - val_loss: 0.4762 - val_accuracy: 0.7376
# Epoch 24/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.3576 - accuracy: 0.8323 - val_loss: 0.3978 - val_accuracy: 0.8106
# Epoch 25/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3632 - accuracy: 0.8303 - val_loss: 0.4869 - val_accuracy: 0.7443
# Epoch 26/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3499 - accuracy: 0.8403 - val_loss: 0.6656 - val_accuracy: 0.5309
# Epoch 27/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3607 - accuracy: 0.8285 - val_loss: 0.3251 - val_accuracy: 0.9008
# Epoch 28/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3641 - accuracy: 0.8275 - val_loss: 0.6577 - val_accuracy: 0.5460
# Epoch 29/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3569 - accuracy: 0.8266 - val_loss: 0.3011 - val_accuracy: 0.8802
# Epoch 30/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.3547 - accuracy: 0.8324 - val_loss: 0.5724 - val_accuracy: 0.6830
# Epoch 31/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.3474 - accuracy: 0.8369 - val_loss: 0.5429 - val_accuracy: 0.7159
# Epoch 32/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3412 - accuracy: 0.8393 - val_loss: 0.2542 - val_accuracy: 0.9025
# Epoch 33/50
# 420/420 [==============================] - 26s 63ms/step - loss: 0.3408 - accuracy: 0.8432 - val_loss: 0.4159 - val_accuracy: 0.8028
# Epoch 34/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3399 - accuracy: 0.8378 - val_loss: 0.3084 - val_accuracy: 0.8780
# Epoch 35/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3327 - accuracy: 0.8440 - val_loss: 0.2992 - val_accuracy: 0.8702
# Epoch 36/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3337 - accuracy: 0.8451 - val_loss: 0.2721 - val_accuracy: 0.8858
# Epoch 37/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3304 - accuracy: 0.8473 - val_loss: 0.4300 - val_accuracy: 0.8028
# Epoch 38/50
# 420/420 [==============================] - 27s 64ms/step - loss: 0.3208 - accuracy: 0.8520 - val_loss: 0.2778 - val_accuracy: 0.9019
# Epoch 39/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3239 - accuracy: 0.8492 - val_loss: 0.3299 - val_accuracy: 0.8719
# Epoch 40/50
# 420/420 [==============================] - 27s 63ms/step - loss: 0.3211 - accuracy: 0.8543 - val_loss: 0.3058 - val_accuracy: 0.8719
# Epoch 41/50
# 420/420 [==============================] - 27s 63ms/step - loss: 0.3229 - accuracy: 0.8524 - val_loss: 0.3192 - val_accuracy: 0.8747
# Epoch 42/50
# 420/420 [==============================] - 27s 65ms/step - loss: 0.3190 - accuracy: 0.8565 - val_loss: 0.5690 - val_accuracy: 0.6156
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2542 - accuracy: 0.9025
# Improved test accuracy: 0.9025
